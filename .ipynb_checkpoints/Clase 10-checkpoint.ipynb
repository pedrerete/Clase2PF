# %% [markdown]
# # Clase 10

# %%
# Archivos
# Out:
# hola

# %%
#!pip install pandas
import pandas as pd

# %%
df_a = pd.read_csv("C:\\Users\\pesparza\\Desktop\\Curso Python\\Files\\athlete_events.csv")
df_a.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df_p = pd.read_csv("C:\\Users\\pesparza\\Desktop\\Curso Python\\Files\\PopularCreativeTypes.csv")
df_p
# Out:
#    RANK           CREATIVE TYPES MOVIES      TOTAL GROSS AVERAGE GROSS  \
# 0   1.0     Contemporary Fiction  7,442  $96,203,727,036   $12,927,133
# 1   2.0             Kids Fiction    564  $32,035,539,746   $56,800,602
# 2   3.0          Science Fiction    724  $29,922,660,857   $41,329,642
# 3   4.0                  Fantasy    759  $21,724,062,575   $28,621,953
# 4   5.0               Super Hero    129  $20,273,157,911  $157,156,263
# 5   6.0       Historical Fiction  1,487  $18,521,260,744   $12,455,454
# 6   7.0            Dramatization  1,175  $15,715,191,699   $13,374,631
# 7   8.0                  Factual  2,467   $2,960,327,207    $1,199,970
# 8   9.0  Multiple Creative Types     42     $117,574,526    $2,799,393
# 9   NaN                      NaN    NaN              NaN           NaN
#
#   MARKET SHARE
# 0       40.46%
# 1       13.47%
# 2       12.59%
# 3        9.14%
# 4        8.53%
# 5        7.79%
# 6        6.61%
# 7        1.25%
# 8        0.05%
# 9          NaN

# %%
#Filtrar
df=df_a[df_a["Sport"] == 'Judo']
df
# Out:
#             ID                       Name Sex   Age  Height  Weight  \
# 1            2                   A Lamusi   M  23.0   170.0    60.0
# 160         64             M'Bairo Abakar   M  31.0     NaN     NaN
# 180         78               Salim Abanoz   M  26.0     NaN     NaN
# 412        229       Mohamed Ali Abdelaal   M  26.0   175.0    81.0
# 435        242          Ahmed Abdelrahman   M  20.0   165.0    60.0
# ...        ...                        ...  ..   ...     ...     ...
# 270853  135459             Oleg Zurabiani   M  19.0   172.0    64.0
# 270918  135482                Goran uvela   M  27.0   184.0    93.0
# 270981  135503            Zurab Zviadauri   M  23.0   182.0    90.0
# 271032  135535  Claudia Antoinette Zwiers   F  22.0   181.0    78.0
# 271033  135535  Claudia Antoinette Zwiers   F  30.0   181.0    78.0
#
#                 Team  NOC        Games  Year  Season            City Sport  \
# ...

# %%
#Contar
df_a["Sex"].value_counts()
# Out:
# M    196594
# F     74522
# Name: Sex, dtype: int64

# %%
#Mas joven con medalla de oro
df_gold = df_a[df_a["Medal"]=="Gold"]
df_gold2 = df_gold.sort_values(by=["Age"])
edad_min = df_gold["Age"].min()
print("El mas joven con medalla de oro tiene:", int(edad_min), "años")
df_gold2
# Out:
# El mas joven con medalla de oro tiene: 13 años
#             ID                                Name Sex   Age  Height  Weight  \
# 268602  134381                         Klaus Zerta   M  13.0   165.0    48.0
# 52010    26731  Donna Elizabeth de Varona (-Pinto)   F  13.0   168.0    61.0
# 119277   60384                          Kim Yun-Mi   F  13.0   160.0    48.0
# 27207    14142                       Hans Bourquin   M  13.0     NaN     NaN
# 73581    37398                          Fu Mingxia   F  13.0   160.0    48.0
# ...        ...                                 ...  ..   ...     ...     ...
# 251215  125805                    Petros Velliotis   M   NaN     NaN     NaN
# 258487  129432                       Ottokar Weise   M   NaN     NaN     NaN
# 260632  130429                       Josef Wilhelm   M   NaN     NaN     NaN
# 266934  133554                Sayed Muhammad Yusuf   M   NaN     NaN     NaN
# 268232  134198          Walter John "Jack" Zealley   M   NaN     NaN     NaN
# ...

# %%
#Mas veterano con medalla(bronze, plata, oro)
df_medal = df_a[~df_a["Medal"].isna()]
df_medal2 = df_medal.sort_values(by=["Age"], ascending=False)
edad_max = df_medal["Age"].max()
print("El mas veterano con medalla tiene:", int(edad_max), "años")
df_medal2
# Out:
# El mas veterano con medalla tiene: 73 años
#             ID                                           Name Sex   Age  \
# 44584    22984  John (Herbert Crawford-) Copley (Williamson-)   M  73.0
# 60009    30731                                     Jozu Dupon   M  72.0
# 233395  117046                              Oscar Gomer Swahn   M  72.0
# 150755   75648                         Charles William Martin   M  71.0
# 150756   75648                         Charles William Martin   M  71.0
# ...        ...                                            ...  ..   ...
# 268232  134198                     Walter John "Jack" Zealley   M   NaN
# 268511  134323                                     Zdenk emla   M   NaN
# 268512  134323                                     Zdenk emla   M   NaN
# 268540  134344                                  brahim Zengin   M   NaN
# 270358  135239                                Khristos Zorbas   M   NaN
#
# ...

# %%
#Mas ganador y su dataframe
df_winner = df_a["Name"].mode()
df_winner_2 = df_a[df_a["Name"]==df_winner[0]]
df_winner_2
# Out:
#            ID                  Name Sex   Age  Height  Weight    Team  NOC  \
# 154798  77710  Robert Tait McKenzie   M  44.0     NaN     NaN  Canada  CAN
# 154799  77710  Robert Tait McKenzie   M  60.0     NaN     NaN  Canada  CAN
# 154800  77710  Robert Tait McKenzie   M  60.0     NaN     NaN  Canada  CAN
# 154801  77710  Robert Tait McKenzie   M  60.0     NaN     NaN  Canada  CAN
# 154802  77710  Robert Tait McKenzie   M  60.0     NaN     NaN  Canada  CAN
# 154803  77710  Robert Tait McKenzie   M  60.0     NaN     NaN  Canada  CAN
# 154804  77710  Robert Tait McKenzie   M  60.0     NaN     NaN  Canada  CAN
# 154805  77710  Robert Tait McKenzie   M  60.0     NaN     NaN  Canada  CAN
# 154806  77710  Robert Tait McKenzie   M  65.0     NaN     NaN  Canada  CAN
# 154807  77710  Robert Tait McKenzie   M  65.0     NaN     NaN  Canada  CAN
# 154808  77710  Robert Tait McKenzie   M  65.0     NaN     NaN  Canada  CAN
# ...

# %%
print("fin clase 10")
# Out:
# fin clase 10
